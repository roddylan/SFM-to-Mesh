# %%
# %reload_ext autoreload
# %autoreload 2
import numpy as np
from SFM import SFM
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt
import halcon

# %matplotlib inline
mpl.rcParams['figure.dpi']= 200
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       6 import matplotlib as mpl
#       7 import matplotlib.pyplot as plt
# ----> 8 import halcon
#      10 get_ipython().run_line_magic('matplotlib', 'inline')
#      11 mpl.rcParams['figure.dpi']= 200
#
# File ~/Documents/UOFA/2023 S2/CMPUT 428/project/VSFM-to-Mesh/venv/lib/python3.10/site-packages/halcon/__init__.py:16
#       1 """
#       2 ************************************************************
#       3 __init__.py - module entry point
#    (...)
#      12 Software by: MVTec Software GmbH, www.mvtec.com
#      13 """
#      15 # Make everything from operator_set visible when importing halcon.
# ---> 16 from .operator_set import *
#      18 from .ffi import HError, HOperatorError, HTupleConversionError, HNull
#      19 from .hdev_operator import HDevOperatorBase
#
# ...

# %%
path = "datasets/templeRing"
# path = "test1/7_1b_imgs_4"


test1 = SFM(path)
# Out:
# templeR_par.txt: 100%|██████████| 49/49 [00:00<00:00, 92.34it/s]
# README.txt is not an img...
#
# templeR_ang.txt is not an img...
#
# templeR_par.txt is not an img...

# %%
w, h, _ = test1.im[0].shape

# %%
cv2.calibrateCamera
# Out:
# matrix([[1.5204e+03, 0.0000e+00, 3.0232e+02],
#         [0.0000e+00, 1.5259e+03, 2.4687e+02],
#         [0.0000e+00, 0.0000e+00, 1.0000e+00]])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 _, K = halcon.radial_distortion_self_calibration(w, h, .2)
#
# NameError: name 'halcon' is not defined
